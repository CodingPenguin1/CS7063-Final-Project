# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('results/ga_cifar_10_epochs_20_generations.csv')
df = pd.read_csv('results/ga_mnist_10_epochs_5_generations.csv')
df
# Out:
#    Generation  Champion Bitstring Champion Values  Champion Fitness  \
# 0           1        100000100001      (9, 3, 32)         84.803363
# 1           2        110000010000     (13, 2, 16)        101.365318
# 2           3          1100000000      (4, 1, 16)        108.967824
# 3           4           100000011      (2, 1, 64)         90.851304
# 4           5         11100110000      (8, 4, 16)         91.398908
#
#    Average Fitness  Minimum Fitness  Champion Accuracy  Average Accuracy  \
# 0        51.533957        30.599823          95.726669         95.541112
# 1        62.016269        13.793675          94.436668         91.793112
# 2        74.273673        39.661896          93.175390         86.955002
# 3        69.814640        42.586397          95.240005         94.555779
# 4        70.308413        39.558911          95.913330         94.682445
#
#    Minimum Accuracy  Champion Capacity  Average Capacity  Maximum Capacity
# 0         11.236667              22298     262885.433333            694392
# 1         11.236667               7752     146993.600000            607616
# 2         11.236667               3863      85359.366667            398856
# 3         11.236667              15153      78503.633333            330781
# 4         11.236667              14958      80876.733333            398256

# %%
plt.plot(df['Generation'], df['Champion Fitness'], label='Max fit')
plt.plot(df['Generation'], df['Average Fitness'], label='Avg fit')
plt.plot(df['Generation'], df['Minimum Fitness'], label='Min fit')
plt.legend(loc='upper right')
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('Fitness')
plt.show()

# %%
plt.plot(df['Generation'], df['Champion Accuracy'], label='Max acc')
plt.plot(df['Generation'], df['Average Accuracy'], label='Avg acc')
plt.plot(df['Generation'], df['Minimum Accuracy'], label='Min acc')
plt.legend(loc='upper right')
plt.xlabel('Generation')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.show()

# %%
plt.plot(df['Generation'], df['Average Capacity'], label='Avg cap')
plt.plot(df['Generation'], df['Champion Capacity'], label='Min cap')
if 'Maximum Capacity' in df.columns:
    plt.plot(df['Generation'], df['Maximum Capacity'], label='Max cap')
plt.legend(loc='upper right')
plt.xlabel('Generation')
plt.ylabel('Capacity')
plt.title('Capacity')
plt.show()
